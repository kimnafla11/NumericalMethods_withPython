# %%
# 제 8장 방정식의 근 구하기
# 8.1. 방정식의 근 찾아내기
# 수치해석에서 방정식의 근을 구하는 방법은 해석적이 아닌 반복적인 과정을 따르게 되는데 시작은 근을 추측하는것
# 1) 근이 존재할 가능성이 있는 영역을 찾아야한다. -> 방정식의 부호가 바뀌는 구간에서 근이 적어도 하나가 존재할 가능성 있음
# 2) 실제적으로 근을 찾아내기

# 근의 존재여부와 영역을 체계적으로 추정할 수 있는 수학적 원리 두가지
# 1) 중간값 정리
# 2) 평균값 정리

# 8.2. 중간값 정리
# 함수 f(x)가 a<=x<=b에서 연속이며 미분 가능하다고 할 때 임의의 함수값 M이 두 점 사이의 함수값 f(a), f(b)와 다음과 같은 관계가 성립된다면
# f(a)<=M<=f(b)
# 이때 함수값 M을 생산할 수 있는 값 c가 a<x<b에 존재하며 f(c)=M이다

# # 8.3. 평균값 정리

# # 8.4. 근의 존재 여부
# f(x)의 근의 존재 여부를 판단하기 위하여 세 가지 경우가 있음
# 1) 함수값의 부호가 모두 양인 경우, f(a)>0, f(b)>0
# 2) 함수값의 부호가 모두 음인 경우, f(a)<0, f(b)<0
# 3) 두 점에서 함수값의 부호가 다른 경우, f(a)>0, f(b)<0 또는 f(a)<0, f(b)>0

# 1) 함수값의 부호가 모두 양인 경우 -> 평균값 정리에 의하여 그 구간에서 근이 존재하지 않음
# 2) 함수값의 부호가 모두 음인 경우 -> 평균값 정리에 의하여 그 구간에서 근이 존재하지 않음
# 3) 함수값의 부호가 다른 경우 -> 평균값 정리에 의하여 정해진 구간에 f(x)=0을 만족 근이 존재함

# # 8.5 요약
# 1. 두 점에서 함수값의 부호가 같은 경우 그 구간에서 해가 존재하지 않는다.
# 2. 두 점에서 함수값의 부호가 다른 경우 그 구간에서 해가 존재한다.
# -> 해가 있을 것으로 여겨지는 영역이 결정되면, 실제적으로 탐색 알고리즘을 적용하여 방정식의 해를 구하는 과정을 수행하여야한다.
# ex) 이분법, 고정법, Newton-Raphson법, 할선법 등의 방법이 있다

# #과제
# 1. 평균값 정리란?
# a<x<b구간에서 f(b)-f(a)/(b-a)=f'(c)을 만족하는 c가 a<c<b을 만족한다면 해가 존재한다.
# 2. 중간값 정리란?
# a<x<b구간에서
# f(c)=0을 만족하는 c가..
# 3. 임의의 함수 f(x)에 대하여 근의 존재 여부를 판단하는 과정
# 1) 근이 존재할 가능성이 있는 영역을 정한다
# 2) 그 두 점에서 함수값의 부호가 달라지면 해가 존재한다
# 3) 탐색알고리즘을 활용하여 근을 찾아낸다.
